# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt;plt.style.use('fivethirtyeight')
import seaborn as sns;

# %%
df = pd.read_csv('Runners_all_results.csv', error_bad_lines=False, encoding='cp1252')
df
# Out:
# b'Skipping line 26144: expected 20 fields, saw 21\n'
#       BibNumber                  FullName                   SortName  \
# 0             2          Lawrence Cherono          Cherono, Lawrence
# 1             6             Lelisa Desisa             Desisa, Lelisa
# 2             7          Kenneth Kipkemoi          Kipkemoi, Kenneth
# 3             8              Felix Kandie              Kandie, Felix
# 4            11            Geoffrey Kirui            Kirui, Geoffrey
# 5            12             Philemon Rono             Rono, Philemon
# 6            28              Scott Fauble              Fauble, Scott
# 7            24                Jared Ward                Ward, Jared
# 8            10              Festus Talam              Talam, Festus
# 9            15            Benson Kipruto            Kipruto, Benson
# 10           25             Elkanah Kibet             Kibet, Elkanah
# 11           14              Hiroto Inoue              Inoue, Hiroto
# ...

# %%
type(df['AgeOnRaceDay'][0])
# Out:
# numpy.int64

# %%
df.columns
# Out:
# Index(['BibNumber', 'FullName', 'SortName', 'AgeOnRaceDay', 'Gender', 'City',
#        'StateAbbrev', 'StateName', 'Zip', 'CountryOfResAbbrev',
#        'CountryOfResName', 'CountryOfCtzAbbrev', 'CountryOfCtzName',
#        'OfficialTime', 'RankOverall', 'RankOverGender', 'RankOverDivision',
#        'EventGroup', 'SubGroupLabel', 'SubGroup'],
#       dtype='object')

# %%
plt.figure(figsize = (20, 10))
sns.countplot('AgeOnRaceDay', data = df)

# %%
plt.figure(figsize = (20, 10))
sns.countplot('AgeOnRaceDay', data = df, hue = 'Gender')

# %%
p = df.groupby('CountryOfResName').count()['City'].sort_values(ascending=False).head(20)
q = sns.barplot(p.index, s, palette='rainbow')
q.figure.set_size_inches(16,8)
q.set_title("Most popular Country")
# Out:
# Text(0.5, 1.0, 'Most popular Country')

# %%
g = sns.boxplot(x='AgeOnRaceDay', y=df['OfficialTime'].apply(lambda x: x.total_seconds()/3600), data=df, palette="coolwarm")
g.figure.set_size_inches(16,8)
g.set_title("Distribution of finish times per Age group")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-cf0926321766> in <module>
# ----> 1 g = sns.boxplot(x='AgeOnRaceDay', y=df['OfficialTime'].apply(lambda x: x.total_seconds()/3600), data=df, palette="coolwarm")
#       2 g.figure.set_size_inches(16,8)
#       3 g.set_title("Distribution of finish times per Age group")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-20-cf0926321766> in <lambda>(x)
# ...
